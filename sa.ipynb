# %%
# !pip install deepface
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: deepface in c:\basha\anaconda\lib\site-packages (0.0.75)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\basha\anaconda\lib\site-packages (from deepface) (4.5.5.64)
# Requirement already satisfied: numpy>=1.14.0 in c:\basha\anaconda\lib\site-packages (from deepface) (1.20.3)
# Requirement already satisfied: Flask>=1.1.2 in c:\basha\anaconda\lib\site-packages (from deepface) (1.1.2)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\basha\anaconda\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: fire>=0.4.0 in c:\basha\anaconda\lib\site-packages (from deepface) (0.4.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\basha\anaconda\lib\site-packages (from deepface) (1.3.4)
# Requirement already satisfied: gdown>=3.10.1 in c:\basha\anaconda\lib\site-packages (from deepface) (4.4.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\basha\anaconda\lib\site-packages (from deepface) (0.0.12)
# Requirement already satisfied: Pillow>=5.2.0 in c:\basha\anaconda\lib\site-packages (from deepface) (8.4.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\basha\anaconda\lib\site-packages (from deepface) (2.9.1)
# Requirement already satisfied: tqdm>=4.30.0 in c:\basha\anaconda\lib\site-packages (from deepface) (4.62.3)
# Requirement already satisfied: keras>=2.2.0 in c:\basha\anaconda\lib\site-packages (from deepface) (2.9.0)
# Requirement already satisfied: termcolor in c:\basha\anaconda\lib\site-packages (from fire>=0.4.0->deepface) (1.1.0)
# Requirement already satisfied: six in c:\basha\anaconda\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: click>=5.1 in c:\basha\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (8.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\basha\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\basha\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\basha\anaconda\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.2)
# Requirement already satisfied: colorama in c:\basha\anaconda\lib\site-packages (from click>=5.1->Flask>=1.1.2->deepface) (0.4.4)
# Requirement already satisfied: filelock in c:\basha\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (3.3.1)
# Requirement already satisfied: requests[socks] in c:\basha\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (2.26.0)
# Requirement already satisfied: beautifulsoup4 in c:\basha\anaconda\lib\site-packages (from gdown>=3.10.1->deepface) (4.10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\basha\anaconda\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: pytz>=2017.3 in c:\basha\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\basha\anaconda\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: h5py>=2.9.0 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.2.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.19.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.10.0.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.46.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.9.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (14.0.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: setuptools in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (58.0.4)
# Requirement already satisfied: packaging in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (21.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\basha\anaconda\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.26.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\basha\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.37.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\basha\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\basha\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (2.6.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\basha\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\basha\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\basha\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (3.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\basha\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\basha\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\basha\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\basha\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\basha\anaconda\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\basha\anaconda\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\basha\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\basha\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\basha\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\basha\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\basha\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\basha\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (3.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\basha\anaconda\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.2.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\basha\anaconda\lib\site-packages (from packaging->tensorflow>=1.9.0->deepface) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\basha\anaconda\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)

# %%
img1=cv2.imread('ntr.jpg')
plt.imshow(img1[:,:,::-1])
plt.show()
result=DeepFace.analyze(img1,actions=['gender'])
print("Gender : ",result['gender'])
# Out:
# 1/1 [==============================] - 0s 195ms/step
# Gender :  Man
